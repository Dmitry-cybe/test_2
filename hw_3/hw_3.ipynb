# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe() #Вывод основной информации о датасете: информацию о типах данных, число пропусков, средние значения и т.д
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()#Вывод основной информации о датасете: информацию о типах данных, число пропусков, средние значения и т.д
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
class1surv = (df.groupby(["Pclass"])["Survived"].sum()[1]/df['Pclass'].value_counts()[1])*100
class2surv = (df.groupby(["Pclass"])["Survived"].sum()[2]/df['Pclass'].value_counts()[2])*100
class3surv = (df.groupby(["Pclass"])["Survived"].sum()[3]/df['Pclass'].value_counts()[3])*100
print(class1surv,'% - процент выживаемости в первом классе')
print(class2surv,'% - процент выживаемости во втором классе')
print(class3surv,'% - процент выживаемости в третьем классе')
# Out:
# 62.96296296296296 % - процент выживаемости в первом классе
# 47.28260869565217 % - процент выживаемости во втором классе
# 24.236252545824847 % - процент выживаемости в третьем классе

# %%
df_male = df[(df['Sex']=='male')] #Пассажиры мужского рода
df_male_name = df_male['Name'].str.split(' ', expand=True) #Разделение столбца на имя и фамилию
df_male_name.head()
# Out:
#            0        1        2        3     4     5     6
# 0    Braund,      Mr.     Owen   Harris  None  None  None
# 4     Allen,      Mr.  William    Henry  None  None  None
# 5     Moran,      Mr.    James     None  None  None  None
# 6  McCarthy,      Mr.  Timothy        J  None  None  None
# 7   Palsson,  Master.    Gosta  Leonard  None  None  None

# %%
df_male_name[2].value_counts().nlargest(2) #Вывод наиболее часто встречаемых мужских имен
# Out:
# 2
# William    35
# John       25
# Name: count, dtype: int64

# %%
df_female = df[(df['Sex']=='female')] #Пассажиры женского рода
df_female_name = df_female['Name'].str.split(' ', expand=True)#Разделение столбца на имя и фамилию
df_female_name.head()
df_female_name[2].value_counts().nlargest(2) #Вывод наиболее популярного женского имени
# Out:
# 2
# William    13
# Mary        9
# Name: count, dtype: int64

# %%
df_male = df[(df['Sex']=='male')]
df_male1 =  df_male[(df['Pclass']==1)]
df_male_name_сlass1 = df_male1['Name'].str.split(' ', expand=True)
df_male_name_сlass1[2].value_counts().nlargest(2) # вывод наиболее популярного мужского имени в первом классе
# Out:
# <ipython-input-18-d6b4f90c826e>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_male1 =  df_male[(df['Pclass']==1)]
# 2
# William    11
# John        9
# Name: count, dtype: int64

# %%
df_male2 =  df_male[(df['Pclass']==2)]
df_male_name_сlass2 = df_male2['Name'].str.split(' ', expand=True)
df_male_name_сlass2[2].value_counts().nlargest(2) # вывод наиболее популярного мужского имени во втором классе
# Out:
# <ipython-input-20-0e4671bcdc38>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_male2 =  df_male[(df['Pclass']==2)]
# 2
# William    9
# Charles    6
# Name: count, dtype: int64

# %%
df_male3 =  df_male[(df['Pclass']==3)]
df_male_name_сlass3 = df_male3['Name'].str.split(' ', expand=True)
df_male_name_сlass3[2].value_counts().nlargest(2) # вывод наиболее популярного мужского имени в третьем классе
# Out:
# <ipython-input-22-ab0a64bfb94f>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_male3 =  df_male[(df['Pclass']==3)]
# 2
# William    15
# Mr.        11
# Name: count, dtype: int64

# %%
df_female1 =  df_female[(df['Pclass']==1)]
df_female_name_сlass1 = df_female1['Name'].str.split(' ', expand=True)
df_female_name_сlass1[2].value_counts().nlargest(5) # вывод наиболее популярного  женского имени в первом классе
# Out:
# <ipython-input-38-31c2a2a9f408>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_female1 =  df_female[(df['Pclass']==1)]
# 2
# John         4
# Elizabeth    4
# William      4
# Henry        3
# Margaret     3
# Name: count, dtype: int64

# %%
df_female2 =  df_female[(df['Pclass']==2)]
df_female_name_сlass2 = df_female2['Name'].str.split(' ', expand=True)
df_female_name_сlass2[2].value_counts().nlargest(2) # вывод наиболее популярного женского имени во втором классе
# Out:
# <ipython-input-43-f06078356c28>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_female2 =  df_female[(df['Pclass']==2)]
# 2
# William    6
# Samuel     2
# Name: count, dtype: int64

# %%
df_female3 =  df_female[(df['Pclass']==3)]
df_female_name_сlass3 = df_female3['Name'].str.split(' ', expand=True)
df_female_name_сlass3[2].value_counts().nlargest(2) # вывод наиболее популярного женского имени в третьем классе
# Out:
# <ipython-input-42-1624b4880b20>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_female3 =  df_female[(df['Pclass']==3)]
# 2
# Anna    7
# Mary    6
# Name: count, dtype: int64

# %%
df[df['Age']>44] #Вывод часть таблицы с пассажирами, возраст которых больше 44 лет
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 52            53         1       1
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Age']>44)	& (df['Sex']=='male')]#Вывод часть таблицы с пассажирами, возраст которых больше 44 лет  которые мужского пола
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 62            63         0       1     Harris, Mr. Henry Birkhardt  male
# 92            93         0       1     Chaffee, Mr. Herbert Fuller  male
# ..           ...       ...     ...                             ...   ...
# 771          772         0       3         Jensen, Mr. Niels Peder  male
# 789          790         0       1        Guggenheim, Mr. Benjamin  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch       Ticket     Fare    Cabin Embarked
# ...

# %%
result = df['Cabin'].value_counts()[df['Cabin'].value_counts() > 1]#Вывод количества n-местных кабин
count = len(result)
count
# Out:
# 46
